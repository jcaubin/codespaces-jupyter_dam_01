# %% [markdown]
# Validación de CSVs publicados

# %%
import requests
import polars as pl
from io import StringIO
import chardet

# %%
csv_list = [
'https://datos.madrid.es/egob/catalogo/202468-239-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-248-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-236-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-230-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-224-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-245-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-221-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-215-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-209-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-233-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-227-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-242-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-218-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-212-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-206-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-200-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-194-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-191-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-185-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-179-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-173-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-203-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-197-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-188-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-182-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-176-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-170-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-164-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-158-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-155-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-149-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-143-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-137-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-167-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-161-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-152-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-146-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-140-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-134-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-128-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-122-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-119-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-113-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-107-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-101-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-131-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-126-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-116-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-110-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-104-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-98-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-92-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-86-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-83-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-77-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-68-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-67-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-95-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-89-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-80-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-74-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-71-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-64-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-58-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-52-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-49-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-43-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-37-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-31-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-61-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-55-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-46-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-40-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-34-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-28-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-22-intensidad-trafico.csv', 
'https://datos.madrid.es/egob/catalogo/202468-25-intensidad-trafico.csv', 
]

# %%
from io import StringIO
import chardet
import requests
import polars as pl
import pandas as pd

url = 'https://datos.madrid.es/egob/catalogo/300392-11041819-meteorologia-tiempo-real.csv'
response = requests.get(url)
rs = StringIO(response.text)
print(response.apparent_encoding, response.encoding)

txt = response.text
txt2 = response.content.decode(encoding='UTF-8-SIG')

cd = chardet.detect(response.content)
print(cd)


df = pl.read_csv(rs, separator=';' ,encoding=response.apparent_encoding, infer_schema_length=10000)
print(df.schema.dtypes())
print(df.schema.keys())


dfpd = pd.read_csv(StringIO(response.text), sep=';')
print(dfpd.keys())
# Out:
# UTF-8-SIG ISO-8859-1
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}
# [Int64, Int64, Int64, Int64, String, Int64, Int64, Int64, Float64, String, Float64, String, Float64, String, Float64, String, Float64, String, Float64, String, Float64, String, Float64, String, Float64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String, Int64, String]
# odict_keys(['ï»¿PROVINCIA', 'MUNICIPIO', 'ESTACION', 'MAGNITUD', 'PUNTO_MUESTREO', 'ANO', 'MES', 'DIA', 'H01', 'V01', 'H02', 'V02', 'H03', 'V03', 'H04', 'V04', 'H05', 'V05', 'H06', 'V06', 'H07', 'V07', 'H08', 'V08', 'H09', 'V09', 'H10', 'V10', 'H11', 'V11', 'H12', 'V12', 'H13', 'V13', 'H14', 'V14', 'H15', 'V15', 'H16', 'V16', 'H17', 'V17', 'H18', 'V18', 'H19', 'V19', 'H20', 'V20', 'H21', 'V21', 'H22', 'V22', 'H23', 'V23', 'H24', 'V24'])
# ...

# %%
df = pl.read_csv('https://datos.madrid.es/egob/catalogo/202468-25-intensidad-trafico.csv' , separator=';' ,encoding='cp1251', infer_schema_length=10000)
df.schema.dtypes()
# Out:
# [String, Int64, Int64, String, String, Float64, Float64, Float64, Float64]

# %%
import chardet

def detect_encoding(file_path):
    with open(file_path, 'rb') as file:
        detector = chardet.universaldetector.UniversalDetector()
        for line in file:
            detector.feed(line)
            if detector.done:
                break
        detector.close()
    return detector.result['encoding']

# %%
for url in csv_list:
    try:
        df = pl.read_csv(url, separator=';' ,encoding='cp1251', infer_schema_length=10000)
        print(url, df.schema.dtypes())
    except Exception as e:
        print(url, 'Error', e)
# Out:
# https://datos.madrid.es/egob/catalogo/202468-239-intensidad-trafico.csv [String, Int64, Int64, String, String, Float64, Float64, Float64, Float64]
# https://datos.madrid.es/egob/catalogo/202468-248-intensidad-trafico.csv [String, Int64, Int64, String, String, Float64, Float64, Float64, Float64]
# https://datos.madrid.es/egob/catalogo/202468-236-intensidad-trafico.csv [String, Int64, Int64, String, String, Float64, Float64, Float64, Float64]
# https://datos.madrid.es/egob/catalogo/202468-230-intensidad-trafico.csv [String, Int64, Int64, String, String, Float64, Float64, Float64, Float64]
# https://datos.madrid.es/egob/catalogo/202468-224-intensidad-trafico.csv Error 'charmap' codec can't decode byte 0x98 in position 125437: character maps to <undefined>
# https://datos.madrid.es/egob/catalogo/202468-245-intensidad-trafico.csv Error 'charmap' codec can't decode byte 0x98 in position 125437: character maps to <undefined>
# ...

# %%
for url in csv_list:
    try:
        response = requests.get(url)
        rs = StringIO(response.text)
        df = pl.read_csv(rs, separator=';' ,encoding=response.encoding, infer_schema_length=10000)
        cd = chardet.detect(response.content)
        print(url, response.encoding , df.schema.dtypes(), cd)
    except Exception as e:
        print(url, 'Error', e)
# Out:
# https://datos.madrid.es/egob/catalogo/202468-239-intensidad-trafico.csv ISO-8859-1 [String, Int64, Int64, String, String, Float64, Float64, Float64, Float64] {'encoding': 'ISO-8859-1', 'confidence': 0.7299780141925343, 'language': ''}
# https://datos.madrid.es/egob/catalogo/202468-248-intensidad-trafico.csv ISO-8859-1 [String, Int64, Int64, String, String, Float64, Float64, Float64, Float64] {'encoding': 'ISO-8859-1', 'confidence': 0.7299779903289534, 'language': ''}
# https://datos.madrid.es/egob/catalogo/202468-236-intensidad-trafico.csv ISO-8859-1 [String, Int64, Int64, String, String, Float64, Float64, Float64, Float64] {'encoding': 'ISO-8859-1', 'confidence': 0.7299780233013216, 'language': ''}
# https://datos.madrid.es/egob/catalogo/202468-230-intensidad-trafico.csv ISO-8859-1 [String, Int64, Int64, String, String, Float64, Float64, Float64, Float64] {'encoding': 'ISO-8859-1', 'confidence': 0.7299779056326945, 'language': ''}
# ...
